# %% [markdown]
# # 🏀 NBA Simulation Results Analysis
#
# Interactive analysis of your NBA game prediction simulations.

# %%
# Import the notebook-friendly functions
from nba_results_notebook import (
    show_game_summary, 
    show_run_timeline, 
    show_performance_stats,
    quick_summary,
    load_results_df,
    get_successful_runs,
    get_run_details
)

# For additional analysis
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set up plotting style
plt.style.use('default')
sns.set_palette("husl")

# %% [markdown]
# ## 📊 Quick Summary

# %%
# Get a quick overview
quick_summary()
# Out:
# 🏀 6 total runs • ✅ 1 completed • 🎯 1 unique games • 📊 16.7% success rate
# 🏆 Latest: Game 22300803 - SAS 140 - SAC 122 (555 plays)

# %% [markdown]
# ## 🎯 Game Summary Table

# %%
# Show the beautiful game summary table
summary_df = show_game_summary()
summary_df
# Out:
# 🏀 NBA Simulation Results Summary
# ...
# <style type="text/css">
# </style>
# <table id="T_6b646" style="font-size: 12px">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b646_level0_col0" class="col_heading level0 col0" >Game ID</th>
#       <th id="T_6b646_level0_col1" class="col_heading level0 col1" >Season</th>
#       <th id="T_6b646_level0_col2" class="col_heading level0 col2" >Total Sims</th>
#       <th id="T_6b646_level0_col3" class="col_heading level0 col3" >Completed</th>
#       <th id="T_6b646_level0_col4" class="col_heading level0 col4" >Errors</th>
#       <th id="T_6b646_level0_col5" class="col_heading level0 col5" >Success Rate</th>
#       <th id="T_6b646_level0_col6" class="col_heading level0 col6" >Avg Predictions</th>
#       <th id="T_6b646_level0_col7" class="col_heading level0 col7" >Avg Duration (min)</th>
#       <th id="T_6b646_level0_col8" class="col_heading level0 col8" >Final Scores</th>
#     </tr>
#   </thead>
# ...

# %% [markdown]
# ## 📈 Performance Analysis

# %%
# Show performance charts and statistics
show_performance_stats()
# Out:
# c:\Users\micha\nba_predictions\nba_results_notebook.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completed_runs['duration_minutes'] = completed_runs['duration_seconds'] / 60
# c:\Users\micha\nba_predictions\nba_results_notebook.py:195: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   plt.tight_layout()
# c:\Users\micha\nba_predictions\nba_results_notebook.py:195: UserWarning: Glyph 9201 (\N{STOPWATCH}) missing from current font.
#   plt.tight_layout()
# c:\Users\micha\nba_predictions\nba_results_notebook.py:195: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from current font.
#   plt.tight_layout()
# ...

# %% [markdown]
# ## 🔍 Custom Analysis
#
# Load the data as a DataFrame for your own analysis:

# %%
# Load all results as a DataFrame for custom analysis
df = load_results_df()
print(f"Total rows: {len(df)}")
print(f"Columns: {list(df.columns)}")

# Show successful runs only
successful_runs = get_successful_runs()
print(f"\nSuccessful runs: {len(successful_runs)}")

if len(successful_runs) > 0:
    display(successful_runs[['game_id', 'final_score', 'successful_predictions', 'duration_seconds']].head())
else:
    print("No successful runs yet!")
